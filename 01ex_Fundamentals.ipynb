# %% [markdown]
# 0\. Implement a function (whatever you want) and save it to a file (e.g. `function.py`). Import that file and use that function in this notebook.

# %%
import square as sq

sq.square(9)
# Out:
# 81

# %% [markdown]
# 1\. Write the following as a list comprehension

# %%
# 1
ans = []
for i in range(3):
    for j in range(4):
        ans.append((i, j))
print ('ans=', ans)

newans=[]
newans = [(i,j) for i in range(3) for j in range(4)]
print('newans=',newans)


# 2
ans = map(lambda x: x*x, filter(lambda x: x%2 == 0, range(5)))
print (list(ans))
newans=[x*x for x in range(5) if x%2==0]
print(newans)
# Out:
# ans= [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# newans= [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]
# [0, 4, 16]

# %% [markdown]
# 2\. Convert the following function into a pure function with no global variables or side effects

# %%
#x = 5
#def f(alist):
#    for i in range(x):
#         alist.append(i)
#    return alist
#
import copy
alist = [1,2,3]
#ans = f(alist)
#print (ans)
#print (alist) # alist has been changed!
#
def aaa(alist, x):
    lista1=copy.deepcopy(alist)
    for i in range(x):
        lista1.append(i)
    return lista1

res=aaa(alist,5)
print(res)
print(alist)
# Out:
# [1, 2, 3, 0, 1, 2, 3, 4]
# [1, 2, 3]

# %% [markdown]
# 3\. Write a `decorator` hello that makes every wrapped function print “Hello!”, i.e. something like:
#
# ```python
# @hello
# def square(x):
#     return x*x
# ```

# %%
def my_decorator(func):
    def wrapper(x):
        print("Hello!")
        y=func(x)
        print("Hello!")
    return wrapper

@my_decorator
def cube(x):
    print(x**3)
    y=x**3
    return y

y
#cube = my_decorator(cube)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-f4dad7a593ab> in <module>
#      12     return y
#      13
# ---> 14 y
#      15 #cube = my_decorator(cube)
#
# NameError: name 'y' is not defined

# %%
cube(3)
# Out:
# Hello!
# 27
# Hello!

# %% [markdown]
# 4\. Write the factorial function so that it a) does and b) does not use recursion.

# %%
#a)

def factorial_rec(x):
    if x==0:
            return 1
    elif x%1!=0:
        print('only int numbers')
    else:
        return x*factorial_rec(x-1)

print(factorial_rec(4))

#b)
def factorial_nonrec(x):
    if x%1==0: ##per avere solo interi
        if x==0:
            return 1
        else:
            fact=1
            for j in range(x):
                fact*=j+1
            return fact
    else:
        print('only int numbers')
factorial_nonrec(5)
# Out:
# 24
# 120

# %% [markdown]
# 5\. Use HOFs (zip in particular) to compute the weight of a circle, a disk and a sphere, assuming different radii and different densities:
#
# ```python
# densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
# radii = [1,2,3]
# ```
#
# where the entries of the dictionary's values are the linear, superficial and volumetric densities of the materials respectively.
#
# In particular define a list of three lambda functions using a comprehension that computes the circumference, the area and the volume for a given radius.

# %%
from math import pi

densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
radii = [1,2,3]

func=[lambda r: 2*pi*r, lambda r: 4*pi*r**2, lambda r: 4/3*pi*r**3]
for r,fun,a,f,p in zip(radii,func, densities['Al'], densities['Fe'],densities['Pb']):    
    weight_a=[a*fun(r)]
    weight_f=[f*fun(r)]
    weight_p=[p*fun(r)]
    print(weight_a,weight_f,weight_p)
# Out:
# [3.141592653589793] [18.84955592153876] [94.24777960769379]
# [50.26548245743669] [201.06192982974676] [1005.3096491487338]
# [226.19467105846508] [565.4866776461627] [3392.920065876976]

# %% [markdown]
# 6\. Edit the class defintion to add an instance attribute of is_hungry = True to the Dog class. Then add a method called eat() which changes the value of is_hungry to False when called. Figure out the best way to feed each dog and then output “My dogs are hungry.” if all are hungry or “My dogs are not hungry.” if all are not hungry. The final output should look like this:
#
#
#
# `I have 3 dogs.
# Tom is 6.
# Fletcher is 7.
# Larry is 9.
# And they're all mammals, of course.
# My dogs are not hungry.
# `
#
# ```python
# # Parent class
#
#
# ##THIS IS THE ORIGINAL CLASSS###################
#
#
# class dog:
#
#     # Class attribute
#     species = 'mammal'
#
#     # Initializer / Instance attributes
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     # instance method
#     def description(self):
#         return "{} is {} years old".format(self.name, self.age)
#
#     # instance method
#     def speak(self, sound):
#         return "{} says {}".format(self.name, sound)
#
# # Child class (inherits from Dog class)
# class RussellTerrier(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
#
# # Child class (inherits from Dog class)
# class Bulldog(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
# ```

# %%
class dog:

    # Class attribute
    species = 'mammal'
    is_hungry = True
    
    # Initializer / Instance attributes
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # instance method
    def description(self):
        return "{} is {} years old".format(self.name, self.age)

    # instance method
    def speak(self, sound):
        return "{} says {}".format(self.name, sound)
    def eat(is_hungry):
        dog.is_hungry = False
        return is_hungry
    
# Child class (inherits from Dog class)
class RussellTerrier(dog):
    def run(self, speed):
        return "{} runs {}".format(self.name, speed)

# Child class (inherits from Dog class)
class Bulldog(dog):
    def run(self, speed):
        return "{} runs {}".format(self.name, speed)
    
    

d=[dog('Tom', 6),dog('Fletcher', 7),dog('Larry', 9)]

print('I have', len(d), 'dogs.')
for doggos in d:
    print(doggos.name, 'is', doggos.age)
    doggos.eat()
    

print('And they\'re all', dog.species ,  'of course.')

check=False
for doggos in d:
    if doggos.is_hungry == False:
        check=False
    else:
        check=True
if check == False:
    print('My dogs are NOT hungry.')
else:
    print('FEED THE DOGGOS!')
# Out:
# I have 3 dogs.
# Tom is 6
# Fletcher is 7
# Larry is 9
# And they're all mammal of course.
# My dogs are NOT hungry.

# %%
# Out:
# aaa
